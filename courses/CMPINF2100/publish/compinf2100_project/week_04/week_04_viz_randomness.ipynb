# %% [markdown]
# ## CMPINF 2100 Week 04
# # Use Pandas to help visualize the random simulation
# we all user Pandas methods to visualize the random numbers generated in our simulation and their summary statistics.
# ## Import Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generate random numbers
# Let's start with creating 7 random numbers from a uniform Distribution.
#
# We need to initialize the randomm nu ber generator object

# %%
rg = np.random.default_rng(2100)

# %% [markdown]
# Let's replicate generating 7 random numbers 25 times
# Assign the result to a 2D NumPy array

# %%
x = rg.random((7, 25))

# %%
x.shape
# Out:
# (7, 25)

# %%
x.ndim
# Out:
# 2

# %% [markdown]
# Convert the NumPy array into a Pandas DataFrame

# %%
xdf = pd.DataFrame(x)

# %%
# %whos
# Out:
# Variable        Type         Data/Info
# --------------------------------------
# ax              Axes         Axes(0.125,0.11;0.775x0.77)
# fig             Figure       Figure(1200x600)
# np              module       <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# pd              module       <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# plt             module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# rg              Generator    Generator(PCG64)
# x               ndarray      7x25: 175 elems, type `float64`, 1400 bytes
# x_N003_df       DataFrame            0         1      <...>n\n[3 rows x 500 columns]
# xdf             DataFrame             0         1     <...>\n\n[7 rows x 25 columns]
# xdf_more_reps   DataFrame            0         1      <...>n\n[7 rows x 500 columns]

# %%
xdf
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.299037  0.948852  0.266548  0.562460  0.040653  0.362566  0.310743
# 1  0.140621  0.661987  0.717689  0.727011  0.858592  0.330807  0.352472
# 2  0.504814  0.980734  0.177619  0.521766  0.402251  0.041145  0.203472
# 3  0.445145  0.396780  0.455287  0.029069  0.754733  0.658180  0.028312
# 4  0.319739  0.567626  0.389765  0.181006  0.058185  0.205025  0.242565
# 5  0.351708  0.406931  0.525787  0.497786  0.395808  0.745044  0.228118
# 6  0.252510  0.625905  0.720810  0.787546  0.845918  0.461911  0.711858
#
#          7         8         9   ...        15        16        17        18  \
# 0  0.021941  0.227507  0.446769  ...  0.669223  0.841995  0.323752  0.101129
# 1  0.017342  0.203099  0.037879  ...  0.959715  0.344034  0.702449  0.494460
# 2  0.473648  0.539202  0.002559  ...  0.307807  0.930980  0.542243  0.083027
# 3  0.644796  0.357419  0.267659  ...  0.415794  0.774862  0.320069  0.143714
# 4  0.171797  0.587954  0.402204  ...  0.428220  0.098465  0.208184  0.751207
# 5  0.345135  0.860829  0.445399  ...  0.325963  0.533450  0.370350  0.531471
# 6  0.648631  0.870721  0.519543  ...  0.709971  0.048651  0.099627  0.914454
#
#          19        20        21        22        23        24
# 0  0.477719  0.968343  0.613910  0.135589  0.212824  0.407869
# 1  0.543104  0.517650  0.479081  0.059607  0.446262  0.334743
# 2  0.006622  0.511821  0.156086  0.149384  0.790806  0.839081
# 3  0.233343  0.667261  0.512088  0.536866  0.006084  0.060231
# 4  0.023064  0.369426  0.201057  0.222495  0.890561  0.813590
# 5  0.337524  0.517265  0.736357  0.541719  0.001432  0.122851
# 6  0.207777  0.765200  0.912604  0.731434  0.917978  0.831390
#
# [7 rows x 25 columns]

# %%
xdf.info
# Out:
# <bound method DataFrame.info of          0         1         2         3         4         5         6   \
# 0  0.299037  0.948852  0.266548  0.562460  0.040653  0.362566  0.310743
# 1  0.140621  0.661987  0.717689  0.727011  0.858592  0.330807  0.352472
7.000000  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000
# mean   0.431352  0.261308  0.616710  0.515883  0.339585  0.466564  0.487108
# std    0.332369  0.207093  0.200043  0.272502  0.259234  0.404530  0.339952
# min    0.083027  0.006622  0.369426  0.156086  0.059607  0.001432  0.060231
# 25%    0.122421  0.115421  0.514543  0.340069  0.142486  0.109454  0.228797
# 50%    0.494460  0.233343  0.517650  0.512088  0.222495  0.446262  0.407869
# 75%    0.641339  0.407622  0.716230  0.675133  0.539292  0.840683  0.822490
# max    0.914454  0.543104  0.968343  0.912604  0.731434  0.917978  0.839081
#
# [8 rows x 25 columns]

# %%
x.mean(axis=0)
# Out:
# array([0.33051069, 0.65554494, 0.4647863 , 0.47237767, 0.47944854,
#        0.40066837, 0.29679165, 0.3318987 , 0.52096157, 0.30314448,
#        0.47344375, 0.46069332, 0.53912547, 0.5634313 , 0.44361449,
#        0.54524158, 0.51034817, 0.36666782, 0.43135169, 0.26130762,
#        0.61670956, 0.51588311, 0.33958488, 0.46656396, 0.48710793])

# %%
xdf.describe().loc[[ 'mean', 'std']]
# Out:
#             0         1         2         3         4         5         6   \
# mean  0.330511  0.655545  0.464786  0.472378  0.479449  0.400668  0.296792
# std   0.120569  0.234235  0.208451  0.275919  0.350426  0.245806  0.209770
#
#             7         8         9   ...        15        16        17  \
# mean  0.331899  0.520962  0.303144  ...  0.545242  0.510348  0.366668
# std   0.270538  0.275850  0.207959  ...  0.241248  0.357746  0.201672
#
#             18        19        20        21        22        23        24
# mean  0.431352  0.261308  0.616710  0.515883  0.339585  0.466564  0.487108
# std   0.332369  0.207093  0.200043  0.272502  0.259234  0.404530  0.339952
#
# [2 rows x 25 columns]

# %% [markdown]
# ## Visualization
# Boxplot can help visualize the CENTRAL behavior and the VARIATION of COLUMNS in DataFrame!
# Let's us a bloxplot to understand the variabiity in the sample across the REPLICATIONS
# Please remember, the columns in 'xdf' are replication of generating 7 randomm numbers

# %%
fig, ax = plt.subplots(figsize=(12,6))
xdf.boxplot(ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# But the horizzondal green line is NOT the AVERAGE
# let's include the AVERAGE IN THE BOXPLOT

# %%
fig, ax = plt.subplots(figsize=(12,6))
xdf.boxplot(ax=ax, showmeans=True)
plt.show()

# %% [markdown]
# Let's change the green trianagle to a red triangle to make it easier to see the smapl average

# %%
fig, ax = plt.subplots(figsize=(12,6))
xdf.boxplot(ax=ax, showmeans=True, meanprops={'markerfacecolor': 'red', 'markeredgecolor': 'red'})
plt.show()

# %% [markdown]
# But we used far more than just 25 replications in our simulations
# We saw that when thousands of replications were used the SIMULATION behaved like theory
# the CLT showed replcated thousands of time produced a GAUSIAN or bell curve distribution for the averages
# Let's now use 500 repliations to see the variation in the sample average based on 7 random samples!

# %%
rg = np.random.default_rng(2100)

# %%
xdf_more_reps = pd.DataFrame( rg.random( (7, 500) ))

# %%
xdf_more_reps.shape
# Out:
# (7, 500)

# %%
fig, ax = plt.subplots(figsize=(12,6))
xdf_more_reps.boxplot(ax=ax, showmeans=True, meanprops={'markerfacecolor': 'red', 'markeredgecolor': 'red'})
plt.show()

# %% [markdown]
# What happens if we used FEWER random samples to calculate the sample average?
# Let's generate 3 random samples and replicate 500 times

# %%
rg = np.random.default_rng(2100)

# %%
x_N003_df = pd.DataFrame(rg.random((3, 500)))

# %%
x_N003_df.shape
# Out:
# (3, 500)

# %%
type(x_N003_df)
# Out:
# pandas.core.frame.DataFrame

# %%
fig, ax = plt.subplots(figsize=(12,6))
x_N003_df.boxplot(ax=ax, showmeans=True, meanprops={'markerfacecolor': 'red', 'markeredgecolor': 'red'})
plt.show()

# %% [markdown]
# In the (7, 500) plot no average was going above 0.8 but that happens in (3, 500) plot that means there is greater variability in (3, 500). SEM is higher on smaller sample size
#
# What if we generated many more samples per replication
#
# what if the sample average was calculated based on 700 random samples per replication?

# %%
rg = np.random.default_rng(2100)

# %%
x_N700_df = pd.DataFrame(rg.random((700, 500)))

# %%
x_N700_df.shape
# Out:
# (700, 500)

# %%
fig, ax = plt.subplots(figsize=(12,6))
x_N700_df.boxplot(ax=ax, showmeans=True, meanprops={'markerfacecolor': 'red', 'markeredgecolor': 'red'})
plt.show()

# %% [markdown]
# Less variation in the average. SEM is very low

# %%
x_N700_df.describe()
# Out:
#               0           1           2           3           4           5    \
# count  700.000000  700.000000  700.000000  700.000000  700.000000  700.000000
# mean     0.502666    0.499209    0.515235    0.511138    0.494616    0.494265
# std      0.297542    0.286071    0.279486    0.292176    0.290104    0.286177
# min      0.001025    0.004724    0.001928    0.000327    0.000706    0.001061
# 25%      0.236883    0.246823    0.279964    0.244648    0.244000    0.240505
# 50%      0.522891    0.496935    0.506092    0.521897    0.496942    0.503209
# 75%      0.764921    0.753658    0.757300    0.774809    0.736201    0.727830
# max      0.998928    0.998971    0.998305    0.996532    0.998774    0.998426
#
#               6           7           8           9    ...         490  \
# count  700.000000  700.000000  700.000000  700.000000  ...  700.000000
# mean     0.491882    0.493278    0.514488    0.516395  ...    0.495534
# std      0.285187    0.300607    0.291046    0.290293  ...    0.281165
# min      0.000143    0.003504    0.001997    0.001393  ...    0.004989
# 25%      0.254675    0.221986    0.258290    0.272102  ...    0.264289
# 50%      0.471751    0.478639    0.529936    0.519515  ...    0.491983
# 75%      0.737752    0.768432    0.771937    0.763697  ...    0.729314
# max      0.998044    0.999923    0.998978    0.999904  ...    0.990224
#
#               491         492         493         494         495         496  \
# count  700.000000  700.000000  700.000000  700.000000  700.000000  700.000000
# mean     0.500833    0.504856    0.500679    0.513369    0.501433    0.484305
# std      0.291955    0.288236    0.287639    0.296760    0.281035    0.298877
# min      0.002199    0.000675    0.003358    0.000013    0.002818    0.000244
# 25%      0.246167    0.239779    0.260701    0.258726    0.258454    0.221548
# 50%      0.515604    0.515069    0.491981    0.528960    0.489528    0.486678
# 75%      0.752740    0.745922    0.739246    0.766043    0.753807    0.751990
# max      0.999381    0.999355    0.998764    0.998892    0.997649    0.999679
#
#               497         498         499
# count  700.000000  700.000000  700.000000
# mean     0.499629    0.508106    0.487892
# std      0.285886    0.289670    0.294626
# min      0.003219    0.001611    0.000484
# 25%      0.258287    0.254519    0.242274
# 50%      0.506599    0.498400    0.497083
# 75%      0.736181    0.762176    0.733853
# max      0.998259    0.999870    0.995952
#
# [8 rows x 500 columns]

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/10min.html

# %%
#Object creation - Series

# %%
s= pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
#DataFrame

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
