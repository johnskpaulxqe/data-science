# %% [markdown]
# ### CMPINF 2100 WEEK 04
# Columns and Rows in the Pandas DataFrames
# We have seen how to create the DataFrame. We have worked with the .index attribute. We now need to practice selecting columns and rows within the DF

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Create example Data
# We will make the Dictionary about baseball and then convert that Dictionary to a DF

# %%
baseball_dict = {'City': ['Pittsburgh', 'Cincinati', 'Chicago', 'St. Louis', 'Milwaukee'],
                'Team':['Pirates', 'Reds', 'Cubs', 'Cardinals', 'Brewers'],
                'Division': 5 * ['Central'],
                'League': 5 * ['NL']}

# %%
baseball_dict
# Out:
# {'City': ['Pittsburgh', 'Cincinati', 'Chicago', 'St. Louis', 'Milwaukee'],
#  'Team': ['Pirates', 'Reds', 'Cubs', 'Cardinals', 'Brewers'],
#  'Division': ['Central', 'Central', 'Central', 'Central', 'Central'],
#  'League': ['NL', 'NL', 'NL', 'NL', 'NL']}

# %%
baseball_df = pd.DataFrame( baseball_dict,
                          columns=['League', 'Division', 'City', 'Team'])

# %%
baseball_df
# Out:
#   League Division        City       Team
# 0     NL  Central  Pittsburgh    Pirates
# 1     NL  Central   Cincinati       Reds
# 2     NL  Central     Chicago       Cubs
# 3     NL  Central   St. Louis  Cardinals
# 4     NL  Central   Milwaukee    Brewers

# %%
baseball_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   League    5 non-null      object
#  1   Division  5 non-null      object
#  2   City      5 non-null      object
#  3   Team      5 non-null      object
# dtypes: object(4)
# memory usage: 288.0+ bytes

# %% [markdown]
# ## Columns
# ### Selecting columns

# %%
baseball_df['Team']
# Out:
# 0      Pirates
# 1         Reds
# 2         Cubs
# 3    Cardinals
# 4      Brewers
# Name: Team, dtype: object

# %%
baseball_df['Division']
# Out:
# 0    Central
# 1    Central
# 2    Central
# 3    Central
# 4    Central
# Name: Division, dtype: object

# %%
type( baseball_df['Division'] )
# Out:
# pandas.core.series.Series

# %%
baseball_df['Division'].index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# There is another way to access or select a single column and retrurn it as a Series
# The previous way the BRACKET notation
# But this other way is known as the DOT NOTATION

# %%
baseball_df.City
# Out:
# 0    Pittsburgh
# 1     Cincinati
# 2       Chicago
# 3     St. Louis
# 4     Milwaukee
# Name: City, dtype: object

# %% [markdown]
# Still another approach is to use the FORMAL .loc[] attribute for selecting the COLUMN

# %%
baseball_df.loc[:, 'Team']
# Out:
# 0      Pirates
# 1         Reds
# 2         Cubs
# 3    Cardinals
# 4      Brewers
# Name: Team, dtype: object

# %%
baseball_df.loc[:, 'Division' ]
# Out:
# 0    Central
# 1    Central
# 2    Central
# 3    Central
# 4    Central
# Name: Division, dtype: object

# %%
baseball_df.loc[:, 'City']
# Out:
# 0    Pittsburgh
# 1     Cincinati
# 2       Chicago
# 3     St. Louis
# 4     Milwaukee
# Name: City, dtype: object

# %%
type(baseball_df.loc[:, 'City'])
# Out:
# pandas.core.series.Series

# %%
baseball_df.iloc[:, 0]
# Out:
# 0    NL
# 1    NL
# 2    NL
# 3    NL
# 4    NL
# Name: League, dtype: object

# %%
baseball_df.iloc[:, -1]
# Out:
# 0      Pirates
# 1         Reds
# 2         Cubs
# 3    Cardinals
# 4      Brewers
# Name: Team, dtype: object

# %%
baseball_df.loc[:, 'Team']
# Out:
# 0      Pirates
# 1         Reds
# 2         Cubs
# 3    Cardinals
# 4      Brewers
# Name: Team, dtype: object

# %%
baseball_df.columns
# Out:
# Index(['League', 'Division', 'City', 'Team'], dtype='object')

# %% [markdown]
# However, be very careful...with how you ENTER or TYPE the column names!

# %%
baseball_df.loc[:,'Team']
# Out:
# 0      Pirates
# 1         Reds
# 2         Cubs
# 3    Cardinals
# 4      Brewers
# Name: Team, dtype: object

# %%
baseball_df.loc[:, ['Team'] ]
# Out:
#         Team
# 0    Pirates
# 1       Reds
# 2       Cubs
# 3  Cardinals
# 4    Brewers

# %%
baseball_df.loc[:, ['Team', 'City'] ]
# Out:
#         Team        City
# 0    Pirates  Pittsburgh
# 1       Reds   Cincinati
# 2       Cubs     Chicago
# 3  Cardinals   St. Louis
# 4    Brewers   Milwaukee

# %% [markdown]
# we need the base Python List to SELECT multiple columns from the Dataframe!!!

# %% [markdown]
# ### Adding and Deleting columns
# Adding columns simliar to how we added new KEY/Values pairs to Dictionaries
# Let's start with the VSLUE that will be added

# %%
baseball_df
# Out:
#   League Division        City       Team
# 0     NL  Central  Pittsburgh    Pirates
# 1     NL  Central   Cincinati       Reds
# 2     NL  Central     Chicago       Cubs
# 3     NL  Central   St. Louis  Cardinals
# 4     NL  Central   Milwaukee    Brewers

# %%
baseball_df['games_back'] = [31.5, 27.5, 22.5, 0, 7.5]

# %%
baseball_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   League      5 non-null      object
#  1   Division    5 non-null      object
#  2   City        5 non-null      object
#  3   Team        5 non-null      object
#  4   games_back  5 non-null      float64
# dtypes: float64(1), object(4)
# memory usage: 328.0+ bytes

# %%
baseball_df
# Out:
#   League Division        City       Team  games_back
# 0     NL  Central  Pittsburgh    Pirates        31.5
# 1     NL  Central   Cincinati       Reds        27.5
# 2     NL  Central     Chicago       Cubs        22.5
# 3     NL  Central   St. Louis  Cardinals         0.0
# 4     NL  Central   Milwaukee    Brewers         7.5

# %%
baseball_df.sort_values(['games_back'], inplace=True)

# %%
baseball_df
# Out:
#   League Division        City       Team  games_back
# 3     NL  Central   St. Louis  Cardinals         0.0
# 4     NL  Central   Milwaukee    Brewers         7.5
# 2     NL  Central     Chicago       Cubs        22.5
# 1     NL  Central   Cincinati       Reds        27.5
# 0     NL  Central  Pittsburgh    Pirates        31.5

# %% [markdown]
# Let's add anotehr clumn which contains the number of WINS per team
# This new column will be assigned to Pandas Series rather than a list

# %%
baseball_df['wins'] = pd.Series([87,79,64,59,55], index=baseball_df.index)

# %%
baseball_df
# Out:
#   League Division        City       Team  games_back  wins
# 3     NL  Central   St. Louis  Cardinals         0.0    87
# 4     NL  Central   Milwaukee    Brewers         7.5    79
# 2     NL  Central     Chicago       Cubs        22.5    64
# 1     NL  Central   Cincinati       Reds        27.5    59
# 0     NL  Central  Pittsburgh    Pirates        31.5    55

# %%
baseball_df.wins
# Out:
# 3    87
# 4    79
# 2    64
# 1    59
# 0    55
# Name: wins, dtype: int64

# %%
baseball_df['losses'] = pd.Series([63, 70, 85, 90, 94], index=baseball_df.index)

# %%
baseball_df
# Out:
#   League Division        City       Team  games_back  wins  losses
# 3     NL  Central   St. Louis  Cardinals         0.0    87      63
# 4     NL  Central   Milwaukee    Brewers         7.5    79      70
# 2     NL  Central     Chicago       Cubs        22.5    64      85
# 1     NL  Central   Cincinati       Reds        27.5    59      90
# 0     NL  Central  Pittsburgh    Pirates        31.5    55      94

# %% [markdown]
# But what if we want to add a SCALAR or CONSTANT value to the DataFrame?
# For e.g. I want a column named 'season' to store the year the data came from
# At first we might think we need to do the following to add the column:

# %%
pd.Series([2022,2022,2022,2022,2022], index=baseball_df.index)
# Out:
# 3    2022
# 4    2022
# 2    2022
# 1    2022
# 0    2022
# dtype: int64

# %%
pd.Series(5*[2022], index=baseball_df.index)
# Out:
# 3    2022
# 4    2022
# 2    2022
# 1    2022
# 0    2022
# dtype: int64

# %% [markdown]
# But we don't need to do these just add the following and Pandas will replicate the constant value donw all the rows of the new column

# %%
baseball_df['season']=2022

# %%
baseball_df
# Out:
#   League Division        City       Team  games_back  wins  losses  season
# 3     NL  Central   St. Louis  Cardinals         0.0    87      63    2022
# 4     NL  Central   Milwaukee    Brewers         7.5    79      70    2022
# 2     NL  Central     Chicago       Cubs        22.5    64      85    2022
# 1     NL  Central   Cincinati       Reds        27.5    59      90    2022
# 0     NL  Central  Pittsburgh    Pirates        31.5    55      94    2022

# %% [markdown]
# ## Deleting or Dropping columns
# We can remove columns through the .drop() method

# %%
baseball_df.drop(columns=['season'])
# Out:
#   League Division        City       Team  games_back  wins  losses
# 3     NL  Central   St. Louis  Cardinals         0.0    87      63
# 4     NL  Central   Milwaukee    Brewers         7.5    79      70
# 2     NL  Central     Chicago       Cubs        22.5    64      85
# 1     NL  Central   Cincinati       Reds        27.5    59      90
# 0     NL  Central  Pittsburgh    Pirates        31.5    55      94

# %%
baseball_df.drop(columns=['wins', 'losses', 'season'])
# Out:
#   League Division        City       Team  games_back
# 3     NL  Central   St. Louis  Cardinals         0.0
# 4     NL  Central   Milwaukee    Brewers         7.5
# 2     NL  Central     Chicago       Cubs        22.5
# 1     NL  Central   Cincinati       Reds        27.5
# 0     NL  Central  Pittsburgh    Pirates        31.5

# %%
baseball_df
# Out:
#   League Division        City       Team  games_back  wins  losses  season
# 3     NL  Central   St. Louis  Cardinals         0.0    87      63    2022
# 4     NL  Central   Milwaukee    Brewers         7.5    79      70    2022
# 2     NL  Central     Chicago       Cubs        22.5    64      85    2022
# 1     NL  Central   Cincinati       Reds        27.5    59      90    2022
# 0     NL  Central  Pittsburgh    Pirates        31.5    55      94    2022

# %% [markdown]
# we sould need to set the implace argument to True to RETAIN or Keep the resulting DataFrame that has FEWER columns!

# %% [markdown]
# ## Setting Rows
# We know how to use the .loc[] and .iloc[] attributes to select rows based on the .index attribute

# %%
baseball_df.loc[3] #everything assoicated with '3'
# Out:
# League               NL
# Division        Central
# City          St. Louis
# Team          Cardinals
# games_back          0.0
# wins                 87
# losses               63
# season             2022
# Name: 3, dtype: object

# %%
baseball_df.iloc[3] #everthing associated with index 3\
# Out:
# League               NL
# Division        Central
# City          Cincinati
# Team               Reds
# games_back         27.5
# wins                 59
# losses               90
# season             2022
# Name: 1, dtype: object

# %% [markdown]
# Conditionally subset the rows

# %%
baseball_df.wins > 65
# Out:
# 3     True
# 4     True
# 2    False
# 1    False
# 0    False
# Name: wins, dtype: bool

# %%
baseball_df.loc[ baseball_df.wins > 65]
# Out:
#   League Division       City       Team  games_back  wins  losses  season
# 3     NL  Central  St. Louis  Cardinals         0.0    87      63    2022
# 4     NL  Central  Milwaukee    Brewers         7.5    79      70    2022

# %%
baseball_df.loc[ baseball_df['wins'] > 65]
# Out:
#   League Division       City       Team  games_back  wins  losses  season
# 3     NL  Central  St. Louis  Cardinals         0.0    87      63    2022
# 4     NL  Central  Milwaukee    Brewers         7.5    79      70    2022

# %%
baseball_df.loc[ baseball_df.wins > 65, :] # official way to say return all the columns that matches the  condition
# Out:
#   League Division       City       Team  games_back  wins  losses  season
# 3     NL  Central  St. Louis  Cardinals         0.0    87      63    2022
# 4     NL  Central  Milwaukee    Brewers         7.5    79      70    2022

# %% [markdown]
# we can select a subset of the columns by providing a LIST of column names!

# %%
baseball_df.loc[ baseball_df.wins > 65, ['Team', 'wins', 'losses']]
# Out:
#         Team  wins  losses
# 3  Cardinals    87      63
# 4    Brewers    79      70

# %% [markdown]
# we can also FILTER by strings. For e.g, lets find the row where Team =='Brewers'

# %%
baseball_df.loc[ baseball_df.Team == 'Brewers', :]
# Out:
#   League Division       City     Team  games_back  wins  losses  season
# 4     NL  Central  Milwaukee  Brewers         7.5    79      70    2022

# %%
baseball_df.loc[ baseball_df.Team == 'Pirates', :]
# Out:
#   League Division        City     Team  games_back  wins  losses  season
# 0     NL  Central  Pittsburgh  Pirates        31.5    55      94    2022

# %% [markdown]
# If you want to match or FILTER based on MULTIPLE conditions you need to use () to separate each condition.
# For e.g. let's find brewers or cardinals

# %%
baseball_df.loc[ (baseball_df.Team == 'Brewers') | (baseball_df.Team == 'Cardinals'), :]
# Out:
#   League Division       City       Team  games_back  wins  losses  season
# 3     NL  Central  St. Louis  Cardinals         0.0    87      63    2022
# 4     NL  Central  Milwaukee    Brewers         7.5    79      70    2022

# %% [markdown]
# We can also have an AND operation
# I want to find all rows where Team is equal to Cardinals AND the wins is greater than 65

# %%
baseball_df.loc[ (baseball_df.Team == 'Cardinals') & (baseball_df.wins > 65), :]
# Out:
#   League Division       City       Team  games_back  wins  losses  season
# 3     NL  Central  St. Louis  Cardinals         0.0    87      63    2022

# %% [markdown]
# ## Summary
# We have seen how to select COLUMNS using BRACKET and DOT notations.
# We have seen how to select MULTIPLE columns.
# We have seen how to select ROWS based on '.index' attribute via '.loc[]' and '.iloc[]'.
# We have seen how to select ROWWS based on conditions (Filtering rows)
# We also saw how to add and remore (drop) columns
