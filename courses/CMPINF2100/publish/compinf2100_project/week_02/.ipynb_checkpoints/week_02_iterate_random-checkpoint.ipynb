# %% [markdown]
# ### CMPINF 2100 week 02
# calling multiple random numbers
# ## Bringing all aspects

# %%
import random

# %%
random.seed(2100)
print(random.random())
print(random.random())
# Out:
# 0.764021138054951
# 0.4692037101382426

# %%
random.seed(2100)
for num in range(10):
    print(random.random())
# Out:
# 0.764021138054951
# 0.4692037101382426
# 0.09010549233469012
# 0.08980190601697957
# 0.5561956463771123
# 0.41097303757112746
# 0.6979324821652212
# 0.9157019989699348
# 0.06734286989910154
# 0.7015550970478079

# %% [markdown]
# to store the values we need to initialize the list

# %%
xu = []

# %%
random.seed(2100)
for n in range(3):
    xu.append(random.random())

# %%
xu
# Out:
# [0.764021138054951, 0.4692037101382426, 0.09010549233469012]

# %% [markdown]
# ## List comprehension

# %%
y = [random.random() for iterating_value in range(12)]

# %%
y
# Out:
# [0.08980190601697957,
#  0.5561956463771123,
#  0.41097303757112746,
#  0.6979324821652212,
#  0.9157019989699348,
#  0.06734286989910154,
#  0.7015550970478079,
#  0.11078753610950587,
#  0.9379189789375049,
#  0.2987506098933619,
#  0.7342115932077558,
#  0.8939978976343719]

# %%
y2 = [random.random() for _ in range(12)]

# %%
y2
# Out:
# [0.36690797563632527,
#  0.7840449290430325,
#  0.37956664277465757,
#  0.6333253705111195,
#  0.3605664070992006,
#  0.7231215087463677,
#  0.07281302170746007,
#  0.6669762270729921,
#  0.4942428713031397,
#  0.7956962831040792,
#  0.552986632512965,
#  0.4893355644568754]
