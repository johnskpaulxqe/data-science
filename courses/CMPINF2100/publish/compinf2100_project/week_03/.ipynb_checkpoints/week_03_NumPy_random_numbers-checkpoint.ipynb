# %% [markdown]
# ## CMPINF 2100 Week 03
# #### Generating random numbers with NumPy
# NumPy greatly streamlines the process of generating many random numbers

# %%
import numpy as np

# %% [markdown]
# ### Random number generators
# NumPy has its own family of random number generators. It requires that we initialize or sepcify the GENERATOR object

# %%
rg = np.random.default_rng(1234)

# %%
# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# np         module       <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# rg         Generator    Generator(PCG64)

# %% [markdown]
# Generating random numbers required calling methods
# The uniform number between 0 and 1 is created using the rg.random() method

# %%
rg.random()
# Out:
# 0.9766997666981422

# %%
rg.random()
# Out:
# 0.3801957350196178

# %%
rg = np.random.default_rng(1234)
print( rg.random(), rg.random(), rg.random())
# Out:
# 0.9766997666981422 0.3801957350196178 0.9232462337639554

# %%
rg = np.random.default_rng(1234)

# %%
rg.random(3)
# Out:
# array([0.97669977, 0.38019574, 0.92324623])

# %%
rg.random(1001).mean()
# Out:
# 0.49614336865861586

# %%
rg = np.random.default_rng(1234)

# %%
rg.random((4, 2))
# Out:
# array([[0.97669977, 0.38019574],
#        [0.92324623, 0.26169242],
#        [0.31909706, 0.11809123],
#        [0.24176629, 0.31853393]])

# %%
rg.random((1000, 10)).shape
# Out:
# (1000, 10)

# %% [markdown]
# ### Other distributions

# %%
help( np.random.random )
# Out:
# Help on built-in function random:
#
# random(...) method of numpy.random.mtrand.RandomState instance
#     random(size=None)
#
#     Return random floats in the half-open interval [0.0, 1.0). Alias for
#     `random_sample` to ease forward-porting to the new random API.

# %%
help( np.random.normal )
# Out:
# Help on built-in function normal:
#
# normal(...) method of numpy.random.mtrand.RandomState instance
#     normal(loc=0.0, scale=1.0, size=None)
#
#     Draw random samples from a normal (Gaussian) distribution.
#
#     The probability density function of the normal distribution, first
#     derived by De Moivre and 200 years later by both Gauss and Laplace
#     independently [2]_, is often called the bell curve because of
#     its characteristic shape (see the example below).
#
#     The normal distributions occurs often in nature.  For example, it
#     describes the commonly occurring distribution of samples influenced
#     by a large number of tiny, random disturbances, each with its own
#     unique distribution [2]_.
#
#     .. note::
#         New code should use the `~numpy.random.Generator.normal`
#         method of a `~numpy.random.Generator` instance instead;
#         please see the :ref:`random-quick-start`.
#
#     Parameters
#     ----------
# ...

# %% [markdown]
# to generate 7 random numbers from a Gaussian or Bell Curve with mean -100 and standard deviation 5

# %%
rg = np.random.default_rng(1234)

# %%
rg.normal( -100, 5, 7)
# Out:
# array([-108.01918403,  -99.67950043,  -96.29554352,  -99.23690403,
#         -95.68128054,  -85.43450389, -107.3941168 ])

# %%
rg.normal( -100, 5, (4, 2))
# Out:
# array([[ -95.27263513, -108.33067729],
#        [ -98.28127709, -102.56221855],
#        [ -93.38120522, -104.30140097],
#        [ -97.402534  , -106.32571859]])
