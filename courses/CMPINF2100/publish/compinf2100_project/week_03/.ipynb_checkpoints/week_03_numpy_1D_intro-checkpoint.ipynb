# %% [markdown]
# ## CMPINF 2100 Week 03
# ### Introduction to 1D NumPy arrays
# NumPy is allowed Python to any kind of Data Analysis.
# NumPy is a moduel and we need to import it

# %%
import numpy as np

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# np         module    <module 'numpy' from '/op<...>kages/numpy/__init__.py'>

# %% [markdown]
# ## NumPy 1D Array
# the **ndarray** is the horse of NumPy. Let's start with 1D array
# ### Create 1D arrays

# %%
np.arange(6)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
a_list = list(range(6))

# %%
 a = np.arange(6)

# %%
dir(a)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__class_getitem__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__dlpack__',
#  '__dlpack_device__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
# ...

# %% [markdown]
# Similar between array and list - we can slice/index bothe objects

# %%
a[:3]
# Out:
# array([0, 1, 2])

# %% [markdown]
# ### Attributes

# %%
len(a_list)
# Out:
# 6

# %% [markdown]
# a.ndim

# %%
a.shape
# Out:
# (6,)

# %%
a.size
# Out:
# 6

# %%
type(a.shape)
# Out:
# tuple

# %%
a
# Out:
# array([0, 1, 2, 3, 4, 5])

# %% [markdown]
# ### Other ways to create arrays
# One way to make array is with np.array() runction. This let us CONVERT a LIST or a TUPLE to an array

# %%
a1 = np.array([1,2,3,4,5])

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          ndarray    6: 6 elems, type `int64`, 48 bytes
# a1         ndarray    5: 5 elems, type `int64`, 40 bytes
# a_list     list       n=6
# np         module     <module 'numpy' from '/op<...>kages/numpy/__init__.py'>

# %%
a1.ndim
# Out:
# 1

# %%
a1.shape
# Out:
# (5,)

# %%
a1.size
# Out:
# 5

# %%
a1
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(a1)
# Out:
# [1 2 3 4 5]

# %%
a2 = np.array((1,2,3,4,5))

# %%
a2
# Out:
# array([1, 2, 3, 4, 5])

# %%
a2.ndim
# Out:
# 1

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.ones(4)
# Out:
# array([1., 1., 1., 1.])

# %% [markdown]
# The 'np.arange()' function has 3 arguments
# START, STOP (EXCLUSIVE), and STEP

# %%
np.arange(4)
# Out:
# array([0, 1, 2, 3])

# %%
np.arange(0, 6, 2)
# Out:
# array([0, 2, 4])

# %%
np.arange(0, 100, 20)
# Out:
# array([ 0, 20, 40, 60, 80])

# %%
np.arange(0, 100+1, 20) # to include the ending number
# Out:
# array([  0,  20,  40,  60,  80, 100])

# %% [markdown]
# the np.linspace() function is very similar to np.arange() BUT..
# START, STOP(INCLUSIVE) and number of points

# %%
np.linspace(0,6, num=1)
# Out:
# array([0.])

# %%
np.linspace(0,6, num=6)
# Out:
# array([0. , 1.2, 2.4, 3.6, 4.8, 6. ])

# %%
np.linspace(0,6, num=6+1)
# Out:
# array([0., 1., 2., 3., 4., 5., 6.])

# %%
np.arange(-10, 10, 3)
# Out:
# array([-10,  -7,  -4,  -1,   2,   5,   8])

# %%
np.linspace(-10, 10, num=17)
# Out:
# array([-10.  ,  -8.75,  -7.5 ,  -6.25,  -5.  ,  -3.75,  -2.5 ,  -1.25,
#          0.  ,   1.25,   2.5 ,   3.75,   5.  ,   6.25,   7.5 ,   8.75,
#         10.  ])

# %% [markdown]
# ### Differences
# operators may behave differently on NumPy arrays compared to lists

# %%
a_list
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
a_list == [0,1,2,3,4,5]
# Out:
# True

# %%
a
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
a == np.array([0,1,2,3,4,5])
# Out:
# array([ True,  True,  True,  True,  True,  True])

# %%
np.array_equal(a, np.array([-10, 1,2,3,4,5]))
# Out:
# False
