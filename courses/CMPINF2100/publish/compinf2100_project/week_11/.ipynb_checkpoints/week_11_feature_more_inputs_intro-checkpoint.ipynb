# %% [markdown]
# ### CMPINF 2100 Week 11
# ### Introduction to working with more than 1 input
#
# We will learn the basics of working with more than 1 input by focusing on 2 inputs in this notebook
#
# We will focus on INTERPRETATION in this notebook rather than FITTING models

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ## Introduction
#
# We know how to work with 1 CONDITION input in our LINEAR MODELS for REGRESSION
#
# Let's begin with ADDITIVE LINEAR relationships

# %% [markdown]
# ### Additive
# #### Linear relationships
#
# We will define a function that calculates the AVERAGE OUPUT or TREND given input 1 and input 2 and the 3 regression coefficients
#
# The purpose of this function is to allow visualizing the TREND with respect to input 1

# %%
def calc_trend_wrt_x1(x1, x2, b0, b1, b2):
    res_df = pd.DataFrame({'x1':x1})
    res_df['x2'] = x2
    res_df['trend'] = b0 + b1 * res_df.x1 + b2 * res_df.x2
    return res_df

# %% [markdown]
# To demonstrate the relationships, let's define the following COEFFICIENTS.

# %%
b0 = -0.25
b1 = 1.95
b2 = 0.2

# %% [markdown]
# Let's now define 101 evenly or uniformly spaced values of `x1` between -3 and 3

# %%
x1_values = np.linspace(-3, 3, num=101)

# %%
x1_values.size
# Out:
# 101

# %%
x1_values.ndim
# Out:
# 1

# %% [markdown]
# Let's calculate the AVERAGE OUTPUT for a SINGLE value of `x2` at 0

# %%
calc_trend_wrt_x1( x1_values, 0, b0, b1, b2)
# Out:
#        x1  x2  trend
# 0   -3.00   0 -6.100
# 1   -2.94   0 -5.983
# 2   -2.88   0 -5.866
# 3   -2.82   0 -5.749
# 4   -2.76   0 -5.632
# ..    ...  ..    ...
# 96   2.76   0  5.132
# 97   2.82   0  5.249
# 98   2.88   0  5.366
# 99   2.94   0  5.483
# 100  3.00   0  5.600
#
# [101 rows x 3 columns]

# %%
calc_trend_wrt_x1( x1_values, 0, b0, b1, b2).x2.value_counts()
# Out:
# x2
# 0    101
# Name: count, dtype: int64

# %% [markdown]
# Let's visualize the RELATIONSHIP between the AVERAGE OUTPUT and INPUT 1

# %%
sns.relplot( data = calc_trend_wrt_x1(x1_values, 0, b0, b1, b2),
            x='x1', y='trend', kind='line')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# But now what happens if we CHANGE `x2` from 0 to -2???

# %%
calc_trend_wrt_x1( x1_values, -2, b0, b1, b2 )
# Out:
#        x1  x2  trend
# 0   -3.00  -2 -6.500
# 1   -2.94  -2 -6.383
# 2   -2.88  -2 -6.266
# 3   -2.82  -2 -6.149
# 4   -2.76  -2 -6.032
# ..    ...  ..    ...
# 96   2.76  -2  4.732
# 97   2.82  -2  4.849
# 98   2.88  -2  4.966
# 99   2.94  -2  5.083
# 100  3.00  -2  5.200
#
# [101 rows x 3 columns]

# %%
sns.relplot( data = calc_trend_wrt_x1(x1_values, -2, b0, b1, b2),
            x='x1', y='trend', kind='line')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Let's REPEAT or REPLICATE calculating the TREND with respect to `x1` FOR different values of `x2`!

# %%
x2_values = np.linspace(-3, 3, num=9)

# %%
x2_values
# Out:
# array([-3.  , -2.25, -1.5 , -0.75,  0.  ,  0.75,  1.5 ,  2.25,  3.  ])

# %% [markdown]
# We could use a for-loop to ITERATE but let's review LIST COMPREHENSIONS!!!

# %%
study_wrt_x1_list = [ calc_trend_wrt_x1(x1_values, x2, b0, b1, b2) for x2 in x2_values ]

# %%
len(study_wrt_x1_list)
# Out:
# 9

# %%
study_wrt_x1_list[0]
# Out:
#        x1   x2  trend
# 0   -3.00 -3.0 -6.700
# 1   -2.94 -3.0 -6.583
# 2   -2.88 -3.0 -6.466
# 3   -2.82 -3.0 -6.349
# 4   -2.76 -3.0 -6.232
# ..    ...  ...    ...
# 96   2.76 -3.0  4.532
# 97   2.82 -3.0  4.649
# 98   2.88 -3.0  4.766
# 99   2.94 -3.0  4.883
# 100  3.00 -3.0  5.000
#
# [101 rows x 3 columns]

# %%
study_wrt_x1_list[1]
# Out:
#        x1    x2  trend
# 0   -3.00 -2.25 -6.550
# 1   -2.94 -2.25 -6.433
# 2   -2.88 -2.25 -6.316
# 3   -2.82 -2.25 -6.199
# 4   -2.76 -2.25 -6.082
# ..    ...   ...    ...
# 96   2.76 -2.25  4.682
# 97   2.82 -2.25  4.799
# 98   2.88 -2.25  4.916
# 99   2.94 -2.25  5.033
# 100  3.00 -2.25  5.150
#
# [101 rows x 3 columns]

# %% [markdown]
# Let's combine or CONCACT the separate DataFrames together

# %%
study_wrt_x1_df = pd.concat( study_wrt_x1_list, ignore_index=True)

# %%
study_wrt_x1_df
# Out:
#        x1   x2  trend
# 0   -3.00 -3.0 -6.700
# 1   -2.94 -3.0 -6.583
# 2   -2.88 -3.0 -6.466
# 3   -2.82 -3.0 -6.349
# 4   -2.76 -3.0 -6.232
# ..    ...  ...    ...
# 904  2.76  3.0  5.732
# 905  2.82  3.0  5.849
# 906  2.88  3.0  5.966
# 907  2.94  3.0  6.083
# 908  3.00  3.0  6.200
#
# [909 rows x 3 columns]

# %%
study_wrt_x1_df.x2.value_counts()
# Out:
# x2
# -3.00    101
# -2.25    101
# -1.50    101
# -0.75    101
#  0.00    101
#  0.75    101
#  1.50    101
#  2.25    101
#  3.00    101
# Name: count, dtype: int64

# %% [markdown]
# Visualize the TREND or AVERAGE OUTPUT with respect `x1` FOR EACH unique values of `x2` as a LINE CHART!!!

# %%
sns.relplot(data = study_wrt_x1_df,
           x='x1', y='trend', kind='line')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# By default Seaborn LINE CHARTS wants to SUMMARIZE data and CALCULATE AVERAGE behavior or the y-axis variable with respect to the x-axis variable!!
#
# Becuase the SCATTER PLOT does NOT average by default

# %%
sns.relplot( data = study_wrt_x1_df,
            x='x1', y='trend', kind='scatter')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# We therefore need to DISABLE or TURN OFF Seaborn's DEFAULT line chart averaging!!
#
# We must tell Seaborn to NOT calculate a SUMMARY estimate!!
#
# We must tell Seaborn What DEFINES each LINE!!! Seaborn refers to this as the UNITS of the line!!!

# %%
sns.relplot(data = study_wrt_x1_df,
           x='x1', y='trend', kind='line',
           estimator=None, units='x2')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# However we cannot tell the difference between the lines! They all have the same color!
#
# We can ASSOCIATE the line color to `x2` via the `hue` argument

# %%
sns.relplot(data = study_wrt_x1_df,
           x='x1', y='trend', kind='line', hue='x2',
           estimator=None, units='x2')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = study_wrt_x1_df,
           x='x1', y='trend', kind='line', hue='x2',
           palette='viridis', estimator=None, units='x2')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = study_wrt_x1_df,
           x='x1', y='trend', kind='line', hue='x2',
           palette='coolwarm', estimator=None, units='x2')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ADDITIVE features ADD the effect of ONE INPUT to the OTHER!!!
#
# If the INPUTS have roughly the same MAGNITUDE and SCSLE the MAGNITUDE of the SCOPE tells you which input causes the GREATER CHANGE on the AVERAGE OUTPUT!!!
#
# Let's see one more time by FOCUSING on the relationship with respect to `x2`.

# %%
def calc_trend_wrt_x2(x1, x2, b0, b1, b2):
    res_df = pd.DataFrame({'x2': x2})
    res_df['x1'] = x1
    res_df['trend'] = b0 + b1 * res_df.x1 + b2 * res_df.x2
    return res_df

# %% [markdown]
# Let's define 2 new arrays so we can visualize the TRENDS with respect to `x2` for different values of `x1`

# %%
x2_values_b = np.linspace(-3, 3, num=101)

# %%
x2_values_b.shape
# Out:
# (101,)

# %%
x1_values_b = np.linspace(-3, 3, num=9)

# %%
x1_values_b
# Out:
# array([-3.  , -2.25, -1.5 , -0.75,  0.  ,  0.75,  1.5 ,  2.25,  3.  ])

# %% [markdown]
# Let's use the LIST COMPREHENSION to iterate over the values of `x1`

# %%
study_wrt_x2_list = [calc_trend_wrt_x2(x1, x2_values_b, b0, b1, b2) for x1 in x1_values_b]

# %%
len(study_wrt_x2_list)
# Out:
# 9

# %%
study_wrt_x2_df = pd.concat( study_wrt_x2_list, ignore_index=True)

# %%
study_wrt_x2_df
# Out:
#        x2   x1  trend
# 0   -3.00 -3.0 -6.700
# 1   -2.94 -3.0 -6.688
# 2   -2.88 -3.0 -6.676
# 3   -2.82 -3.0 -6.664
# 4   -2.76 -3.0 -6.652
# ..    ...  ...    ...
# 904  2.76  3.0  6.152
# 905  2.82  3.0  6.164
# 906  2.88  3.0  6.176
# 907  2.94  3.0  6.188
# 908  3.00  3.0  6.200
#
# [909 rows x 3 columns]

# %%
study_wrt_x2_df.x1.value_counts()
# Out:
# x1
# -3.00    101
# -2.25    101
# -1.50    101
# -0.75    101
#  0.00    101
#  0.75    101
#  1.50    101
#  2.25    101
#  3.00    101
# Name: count, dtype: int64

# %% [markdown]
# Visualize the TREND or AVERAGE OUTPUT with respect to `x2` for each unique value of `x1`. Use the DIVERGING color palette to help distinguish `x1` values ABOVE and BELOW the `x1` MIDPOINT

# %%
sns.relplot(data = study_wrt_x2_df,
           x='x2', y='trend', kind='line', hue='x1',
           palette='coolwarm', estimator=None, units='x1')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
